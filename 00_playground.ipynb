# %%
from har_utils.config import FILE_NAME_SUFFIX
from har_utils.data import get_subject
from har_utils.preprocessing import preprocessing_pipeline
df = get_subject(FILE_NAME_SUFFIX[0])
df.head()
# Out:
#           nose_x  nose_y  left_eye_x  left_eye_y  right_eye_x  right_eye_y  \
# frame_id
# 0          624.0  258.25       628.0      249.50        625.0      249.750
# 1          618.0  260.00       621.5      251.25        618.5      251.625
# 2          611.5  260.50       615.0      252.00        613.0      252.250
# 3          604.0  261.00       608.0      252.50        605.5      252.750
# 4          598.0  260.00       602.5      252.00        600.0      252.000
#
#           left_ear_x  left_ear_y  right_ear_x  right_ear_y  ...  right_hip_y  \
# frame_id                                                    ...
# 0              650.5     252.250        667.5      249.125  ...       441.00
# 1              644.0     254.375        660.5      251.125  ...       440.00
# 2              637.0     256.000        656.5      252.625  ...       441.00
# 3              630.5     256.000        648.5      252.875  ...       443.00
# ...

# %%
from har_utils.features import add_velocity_features

df_mod = add_velocity_features(df)
df_mod.head()
# Out:
#           nose_x  nose_y  left_eye_x  left_eye_y  right_eye_x  right_eye_y  \
# frame_id
# 0          624.0  258.25       628.0      249.50        625.0      249.750
# 1          618.0  260.00       621.5      251.25        618.5      251.625
# 2          611.5  260.50       615.0      252.00        613.0      252.250
# 3          604.0  261.00       608.0      252.50        605.5      252.750
# 4          598.0  260.00       602.5      252.00        600.0      252.000
#
#           left_ear_x  left_ear_y  right_ear_x  right_ear_y  ...  \
# frame_id                                                    ...
# 0              650.5     252.250        667.5      249.125  ...
# 1              644.0     254.375        660.5      251.125  ...
# 2              637.0     256.000        656.5      252.625  ...
# 3              630.5     256.000        648.5      252.875  ...
# 4              623.0     256.750        642.5      253.125  ...
#
# ...

# %%
df_norm = preprocessing_pipeline(df)
df_norm['Action Label'].value_counts()
# Out:
# y hip corrected
# Total Number of Bad Frames where shoulder widht was less than 10: 1377
# Action Label
# Eating snacks      14730
# Sitting quietly    14310
# Walking            13721
# Using phone        10968
# Biting              5610
# Throwing things     4377
# Attacking           4147
# Head banging        3810
# Name: count, dtype: int64
